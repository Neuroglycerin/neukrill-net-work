# %%
import pylearn2.utils
import pylearn2.config
import theano
import neukrill_net.dense_dataset
import neukrill_net.utils
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import holoviews as hl
# %load_ext holoviews.ipython
import sklearn.metrics
# Out:
# Using gpu device 0: Tesla K40c
# :0: FutureWarning: IPython widgets are experimental and may change in the future.
# Welcome to the HoloViews IPython extension! (http://ioam.github.io/holoviews/)
# Available magics: %compositor, %opts, %params, %view, %%labels, %%opts, %%view

# %% [markdown]
# Monitoring Traces at Start
# ==========
#
# The following traces were plotted about one and a half hours after starting the model training.

# %%
m = pylearn2.utils.serial.load(
    "/disk/scratch/neuroglycerin/models/quicker_learning_1_fc_layer_experiment_no_norms_repeat_recent.pkl")

# %%
def make_curves(model, *args):
    curves = None
    for c in args:
        channel = model.monitor.channels[c]
        c = c[0].upper() + c[1:]
        if not curves:
            curves = hl.Curve(zip(channel.example_record,channel.val_record),group=c)
        else:
            curves += hl.Curve(zip(channel.example_record,channel.val_record),group=c)
    return curves

# %%
nll_channels = [c for c in m.monitor.channels.keys() if 'nll' in c]

# %% [markdown]
# Looks like the nll for most of these is still improving, following a fairly linear dropoff. Maybe it'll keep going from here if we keep running it:

# %%
make_curves(m,*nll_channels)
# Out:
#    Train_y_y_1_nll
#       I : Curve.Train_y_y_1_nll   (y)
#    Train_y_y_2_nll
#       I : Curve.Train_y_y_2_nll   (y)
#    Train_y_y_6_nll
#       I : Curve.Train_y_y_6_nll   (y)
#    Train_y_y_3_nll
#       I : Curve.Train_y_y_3_nll   (y)
#    Train_y_y_5_nll
#       I : Curve.Train_y_y_5_nll   (y)
#    Train_y_y_4_nll
#       I : Curve.Train_y_y_4_nll   (y)
#    Valid_y_y_1_nll
#       I : Curve.Valid_y_y_1_nll   (y)
#    Valid_y_y_2_nll
#       I : Curve.Valid_y_y_2_nll   (y)
#    Valid_y_y_6_nll
#       I : Curve.Valid_y_y_6_nll   (y)
#    Valid_y_y_3_nll
#       I : Curve.Valid_y_y_3_nll   (y)
#    Valid_y_y_5_nll
#       I : Curve.Valid_y_y_5_nll   (y)
#    Valid_y_y_4_nll
#       I : Curve.Valid_y_y_4_nll   (y)

# %% [markdown]
# Plotting all the monitoring channels at the same time, could see something interesting happening:

# %%
make_curves(m,*sorted(m.monitor.channels.keys()))
# Out:
#    Learning_rate
#       I : Curve.Learning_rate   (y)
#    Momentum
#       I : Curve.Momentum   (y)
#    Total_seconds_last_epoch
#       I : Curve.Total_seconds_last_epoch   (y)
#    Train_h1_kernel_norms_max
#       I : Curve.Train_h1_kernel_norms_max   (y)
#    Train_h1_kernel_norms_mean
#       I : Curve.Train_h1_kernel_norms_mean   (y)
#    Train_h1_kernel_norms_min
#       I : Curve.Train_h1_kernel_norms_min   (y)
#    Train_h1_max_x_max_u
#       I : Curve.Train_h1_max_x_max_u   (y)
#    Train_h1_max_x_mean_u
#       I : Curve.Train_h1_max_x_mean_u   (y)
#    Train_h1_max_x_min_u
#       I : Curve.Train_h1_max_x_min_u   (y)
#    Train_h1_mean_x_max_u
#       I : Curve.Train_h1_mean_x_max_u   (y)
#    Train_h1_mean_x_mean_u
#       I : Curve.Train_h1_mean_x_mean_u   (y)
#    Train_h1_mean_x_min_u
#       I : Curve.Train_h1_mean_x_min_u   (y)
#    Train_h1_min_x_max_u
#       I : Curve.Train_h1_min_x_max_u   (y)
#    Train_h1_min_x_mean_u
#       I : Curve.Train_h1_min_x_mean_u   (y)
#    Train_h1_min_x_min_u
#       I : Curve.Train_h1_min_x_min_u   (y)
#    Train_h1_range_x_max_u
#       I : Curve.Train_h1_range_x_max_u   (y)
#    Train_h1_range_x_mean_u
#       I : Curve.Train_h1_range_x_mean_u   (y)
#    Train_h1_range_x_min_u
#       I : Curve.Train_h1_range_x_min_u   (y)
#    Train_h2_kernel_norms_max
#       I : Curve.Train_h2_kernel_norms_max   (y)
#    Train_h2_kernel_norms_mean
#       I : Curve.Train_h2_kernel_norms_mean   (y)
#    Train_h2_kernel_norms_min
#       I : Curve.Train_h2_kernel_norms_min   (y)
#    Train_h2_max_x_max_u
#       I : Curve.Train_h2_max_x_max_u   (y)
#    Train_h2_max_x_mean_u
#       I : Curve.Train_h2_max_x_mean_u   (y)
#    Train_h2_max_x_min_u
#       I : Curve.Train_h2_max_x_min_u   (y)
#    Train_h2_mean_x_max_u
#       I : Curve.Train_h2_mean_x_max_u   (y)
#    Train_h2_mean_x_mean_u
#       I : Curve.Train_h2_mean_x_mean_u   (y)
#    Train_h2_mean_x_min_u
#       I : Curve.Train_h2_mean_x_min_u   (y)
#    Train_h2_min_x_max_u
#       I : Curve.Train_h2_min_x_max_u   (y)
#    Train_h2_min_x_mean_u
#       I : Curve.Train_h2_min_x_mean_u   (y)
#    Train_h2_min_x_min_u
#       I : Curve.Train_h2_min_x_min_u   (y)
#    Train_h2_range_x_max_u
#       I : Curve.Train_h2_range_x_max_u   (y)
#    Train_h2_range_x_mean_u
#       I : Curve.Train_h2_range_x_mean_u   (y)
#    Train_h2_range_x_min_u
#       I : Curve.Train_h2_range_x_min_u   (y)
#    Train_h3_kernel_norms_max
#       I : Curve.Train_h3_kernel_norms_max   (y)
#    Train_h3_kernel_norms_mean
#       I : Curve.Train_h3_kernel_norms_mean   (y)
#    Train_h3_kernel_norms_min
#       I : Curve.Train_h3_kernel_norms_min   (y)
#    Train_h3_max_x_max_u
#       I : Curve.Train_h3_max_x_max_u   (y)
#    Train_h3_max_x_mean_u
#       I : Curve.Train_h3_max_x_mean_u   (y)
#    Train_h3_max_x_min_u
#       I : Curve.Train_h3_max_x_min_u   (y)
#    Train_h3_mean_x_max_u
#       I : Curve.Train_h3_mean_x_max_u   (y)
#    Train_h3_mean_x_mean_u
#       I : Curve.Train_h3_mean_x_mean_u   (y)
#    Train_h3_mean_x_min_u
#       I : Curve.Train_h3_mean_x_min_u   (y)
#    Train_h3_min_x_max_u
#       I : Curve.Train_h3_min_x_max_u   (y)
#    Train_h3_min_x_mean_u
#       I : Curve.Train_h3_min_x_mean_u   (y)
#    Train_h3_min_x_min_u
#       I : Curve.Train_h3_min_x_min_u   (y)
#    Train_h3_range_x_max_u
#       I : Curve.Train_h3_range_x_max_u   (y)
#    Train_h3_range_x_mean_u
#       I : Curve.Train_h3_range_x_mean_u   (y)
#    Train_h3_range_x_min_u
#       I : Curve.Train_h3_range_x_min_u   (y)
#    Train_h4_col_norms_max
#       I : Curve.Train_h4_col_norms_max   (y)
#    Train_h4_col_norms_mean
#       I : Curve.Train_h4_col_norms_mean   (y)
#    Train_h4_col_norms_min
#       I : Curve.Train_h4_col_norms_min   (y)
#    Train_h4_max_x_max_u
#       I : Curve.Train_h4_max_x_max_u   (y)
#    Train_h4_max_x_mean_u
#       I : Curve.Train_h4_max_x_mean_u   (y)
#    Train_h4_max_x_min_u
#       I : Curve.Train_h4_max_x_min_u   (y)
#    Train_h4_mean_x_max_u
#       I : Curve.Train_h4_mean_x_max_u   (y)
#    Train_h4_mean_x_mean_u
#       I : Curve.Train_h4_mean_x_mean_u   (y)
#    Train_h4_mean_x_min_u
#       I : Curve.Train_h4_mean_x_min_u   (y)
#    Train_h4_min_x_max_u
#       I : Curve.Train_h4_min_x_max_u   (y)
#    Train_h4_min_x_mean_u
#       I : Curve.Train_h4_min_x_mean_u   (y)
#    Train_h4_min_x_min_u
#       I : Curve.Train_h4_min_x_min_u   (y)
#    Train_h4_range_x_max_u
#       I : Curve.Train_h4_range_x_max_u   (y)
#    Train_h4_range_x_mean_u
#       I : Curve.Train_h4_range_x_mean_u   (y)
#    Train_h4_range_x_min_u
#       I : Curve.Train_h4_range_x_min_u   (y)
#    Train_h4_row_norms_max
#       I : Curve.Train_h4_row_norms_max   (y)
#    Train_h4_row_norms_mean
#       I : Curve.Train_h4_row_norms_mean   (y)
#    Train_h4_row_norms_min
#       I : Curve.Train_h4_row_norms_min   (y)
#    Train_objective
#       I : Curve.Train_objective   (y)
#    Train_term_0
#       I : Curve.Train_term_0   (y)
#    Train_term_1_weight_decay
#       I : Curve.Train_term_1_weight_decay   (y)
#    Train_y_y_1_col_norms_max
#       I : Curve.Train_y_y_1_col_norms_max   (y)
#    Train_y_y_1_col_norms_mean
#       I : Curve.Train_y_y_1_col_norms_mean   (y)
#    Train_y_y_1_col_norms_min
#       I : Curve.Train_y_y_1_col_norms_min   (y)
#    Train_y_y_1_max_max_class
#       I : Curve.Train_y_y_1_max_max_class   (y)
#    Train_y_y_1_mean_max_class
#       I : Curve.Train_y_y_1_mean_max_class   (y)
#    Train_y_y_1_min_max_class
#       I : Curve.Train_y_y_1_min_max_class   (y)
#    Train_y_y_1_misclass
#       I : Curve.Train_y_y_1_misclass   (y)
#    Train_y_y_1_nll
#       I : Curve.Train_y_y_1_nll   (y)
#    Train_y_y_1_row_norms_max
#       I : Curve.Train_y_y_1_row_norms_max   (y)
#    Train_y_y_1_row_norms_mean
#       I : Curve.Train_y_y_1_row_norms_mean   (y)
#    Train_y_y_1_row_norms_min
#       I : Curve.Train_y_y_1_row_norms_min   (y)
#    Train_y_y_2_col_norms_max
#       I : Curve.Train_y_y_2_col_norms_max   (y)
#    Train_y_y_2_col_norms_mean
#       I : Curve.Train_y_y_2_col_norms_mean   (y)
#    Train_y_y_2_col_norms_min
#       I : Curve.Train_y_y_2_col_norms_min   (y)
#    Train_y_y_2_max_max_class
#       I : Curve.Train_y_y_2_max_max_class   (y)
#    Train_y_y_2_mean_max_class
#       I : Curve.Train_y_y_2_mean_max_class   (y)
#    Train_y_y_2_min_max_class
#       I : Curve.Train_y_y_2_min_max_class   (y)
#    Train_y_y_2_misclass
#       I : Curve.Train_y_y_2_misclass   (y)
#    Train_y_y_2_nll
#       I : Curve.Train_y_y_2_nll   (y)
#    Train_y_y_2_row_norms_max
#       I : Curve.Train_y_y_2_row_norms_max   (y)
#    Train_y_y_2_row_norms_mean
#       I : Curve.Train_y_y_2_row_norms_mean   (y)
#    Train_y_y_2_row_norms_min
#       I : Curve.Train_y_y_2_row_norms_min   (y)
#    Train_y_y_3_col_norms_max
#       I : Curve.Train_y_y_3_col_norms_max   (y)
#    Train_y_y_3_col_norms_mean
#       I : Curve.Train_y_y_3_col_norms_mean   (y)
#    Train_y_y_3_col_norms_min
#       I : Curve.Train_y_y_3_col_norms_min   (y)
#    Train_y_y_3_max_max_class
#       I : Curve.Train_y_y_3_max_max_class   (y)
#    Train_y_y_3_mean_max_class
#       I : Curve.Train_y_y_3_mean_max_class   (y)
#    Train_y_y_3_min_max_class
#       I : Curve.Train_y_y_3_min_max_class   (y)
#    Train_y_y_3_misclass
#       I : Curve.Train_y_y_3_misclass   (y)
#    Train_y_y_3_nll
#       I : Curve.Train_y_y_3_nll   (y)
#    Train_y_y_3_row_norms_max
#       I : Curve.Train_y_y_3_row_norms_max   (y)
#    Train_y_y_3_row_norms_mean
#       I : Curve.Train_y_y_3_row_norms_mean   (y)
#    Train_y_y_3_row_norms_min
#       I : Curve.Train_y_y_3_row_norms_min   (y)
#    Train_y_y_4_col_norms_max
#       I : Curve.Train_y_y_4_col_norms_max   (y)
#    Train_y_y_4_col_norms_mean
#       I : Curve.Train_y_y_4_col_norms_mean   (y)
#    Train_y_y_4_col_norms_min
#       I : Curve.Train_y_y_4_col_norms_min   (y)
#    Train_y_y_4_max_max_class
#       I : Curve.Train_y_y_4_max_max_class   (y)
#    Train_y_y_4_mean_max_class
#       I : Curve.Train_y_y_4_mean_max_class   (y)
#    Train_y_y_4_min_max_class
#       I : Curve.Train_y_y_4_min_max_class   (y)
#    Train_y_y_4_misclass
#       I : Curve.Train_y_y_4_misclass   (y)
#    Train_y_y_4_nll
#       I : Curve.Train_y_y_4_nll   (y)
#    Train_y_y_4_row_norms_max
#       I : Curve.Train_y_y_4_row_norms_max   (y)
#    Train_y_y_4_row_norms_mean
#       I : Curve.Train_y_y_4_row_norms_mean   (y)
#    Train_y_y_4_row_norms_min
#       I : Curve.Train_y_y_4_row_norms_min   (y)
#    Train_y_y_5_col_norms_max
#       I : Curve.Train_y_y_5_col_norms_max   (y)
#    Train_y_y_5_col_norms_mean
#       I : Curve.Train_y_y_5_col_norms_mean   (y)
#    Train_y_y_5_col_norms_min
#       I : Curve.Train_y_y_5_col_norms_min   (y)
#    Train_y_y_5_max_max_class
#       I : Curve.Train_y_y_5_max_max_class   (y)
#    Train_y_y_5_mean_max_class
#       I : Curve.Train_y_y_5_mean_max_class   (y)
#    Train_y_y_5_min_max_class
#       I : Curve.Train_y_y_5_min_max_class   (y)
#    Train_y_y_5_misclass
#       I : Curve.Train_y_y_5_misclass   (y)
#    Train_y_y_5_nll
#       I : Curve.Train_y_y_5_nll   (y)
#    Train_y_y_5_row_norms_max
#       I : Curve.Train_y_y_5_row_norms_max   (y)
#    Train_y_y_5_row_norms_mean
#       I : Curve.Train_y_y_5_row_norms_mean   (y)
#    Train_y_y_5_row_norms_min
#       I : Curve.Train_y_y_5_row_norms_min   (y)
#    Train_y_y_6_col_norms_max
#       I : Curve.Train_y_y_6_col_norms_max   (y)
#    Train_y_y_6_col_norms_mean
#       I : Curve.Train_y_y_6_col_norms_mean   (y)
#    Train_y_y_6_col_norms_min
#       I : Curve.Train_y_y_6_col_norms_min   (y)
#    Train_y_y_6_max_max_class
#       I : Curve.Train_y_y_6_max_max_class   (y)
#    Train_y_y_6_mean_max_class
#       I : Curve.Train_y_y_6_mean_max_class   (y)
#    Train_y_y_6_min_max_class
#       I : Curve.Train_y_y_6_min_max_class   (y)
#    Train_y_y_6_misclass
#       I : Curve.Train_y_y_6_misclass   (y)
#    Train_y_y_6_nll
#       I : Curve.Train_y_y_6_nll   (y)
#    Train_y_y_6_row_norms_max
#       I : Curve.Train_y_y_6_row_norms_max   (y)
#    Train_y_y_6_row_norms_mean
#       I : Curve.Train_y_y_6_row_norms_mean   (y)
#    Train_y_y_6_row_norms_min
#       I : Curve.Train_y_y_6_row_norms_min   (y)
#    Training_seconds_this_epoch
#       I : Curve.Training_seconds_this_epoch   (y)
#    Valid_h1_kernel_norms_max
#       I : Curve.Valid_h1_kernel_norms_max   (y)
#    Valid_h1_kernel_norms_mean
#       I : Curve.Valid_h1_kernel_norms_mean   (y)
#    Valid_h1_kernel_norms_min
#       I : Curve.Valid_h1_kernel_norms_min   (y)
#    Valid_h1_max_x_max_u
#       I : Curve.Valid_h1_max_x_max_u   (y)
#    Valid_h1_max_x_mean_u
#       I : Curve.Valid_h1_max_x_mean_u   (y)
#    Valid_h1_max_x_min_u
#       I : Curve.Valid_h1_max_x_min_u   (y)
#    Valid_h1_mean_x_max_u
#       I : Curve.Valid_h1_mean_x_max_u   (y)
#    Valid_h1_mean_x_mean_u
#       I : Curve.Valid_h1_mean_x_mean_u   (y)
#    Valid_h1_mean_x_min_u
#       I : Curve.Valid_h1_mean_x_min_u   (y)
#    Valid_h1_min_x_max_u
#       I : Curve.Valid_h1_min_x_max_u   (y)
#    Valid_h1_min_x_mean_u
#       I : Curve.Valid_h1_min_x_mean_u   (y)
#    Valid_h1_min_x_min_u
#       I : Curve.Valid_h1_min_x_min_u   (y)
#    Valid_h1_range_x_max_u
#       I : Curve.Valid_h1_range_x_max_u   (y)
#    Valid_h1_range_x_mean_u
#       I : Curve.Valid_h1_range_x_mean_u   (y)
#    Valid_h1_range_x_min_u
#       I : Curve.Valid_h1_range_x_min_u   (y)
#    Valid_h2_kernel_norms_max
#       I : Curve.Valid_h2_kernel_norms_max   (y)
#    Valid_h2_kernel_norms_mean
#       I : Curve.Valid_h2_kernel_norms_mean   (y)
#    Valid_h2_kernel_norms_min
#       I : Curve.Valid_h2_kernel_norms_min   (y)
#    Valid_h2_max_x_max_u
#       I : Curve.Valid_h2_max_x_max_u   (y)
#    Valid_h2_max_x_mean_u
#       I : Curve.Valid_h2_max_x_mean_u   (y)
#    Valid_h2_max_x_min_u
#       I : Curve.Valid_h2_max_x_min_u   (y)
#    Valid_h2_mean_x_max_u
#       I : Curve.Valid_h2_mean_x_max_u   (y)
#    Valid_h2_mean_x_mean_u
#       I : Curve.Valid_h2_mean_x_mean_u   (y)
#    Valid_h2_mean_x_min_u
#       I : Curve.Valid_h2_mean_x_min_u   (y)
#    Valid_h2_min_x_max_u
#       I : Curve.Valid_h2_min_x_max_u   (y)
#    Valid_h2_min_x_mean_u
#       I : Curve.Valid_h2_min_x_mean_u   (y)
#    Valid_h2_min_x_min_u
#       I : Curve.Valid_h2_min_x_min_u   (y)
#    Valid_h2_range_x_max_u
#       I : Curve.Valid_h2_range_x_max_u   (y)
#    Valid_h2_range_x_mean_u
#       I : Curve.Valid_h2_range_x_mean_u   (y)
#    Valid_h2_range_x_min_u
#       I : Curve.Valid_h2_range_x_min_u   (y)
#    Valid_h3_kernel_norms_max
#       I : Curve.Valid_h3_kernel_norms_max   (y)
#    Valid_h3_kernel_norms_mean
#       I : Curve.Valid_h3_kernel_norms_mean   (y)
#    Valid_h3_kernel_norms_min
#       I : Curve.Valid_h3_kernel_norms_min   (y)
#    Valid_h3_max_x_max_u
#       I : Curve.Valid_h3_max_x_max_u   (y)
#    Valid_h3_max_x_mean_u
#       I : Curve.Valid_h3_max_x_mean_u   (y)
#    Valid_h3_max_x_min_u
#       I : Curve.Valid_h3_max_x_min_u   (y)
#    Valid_h3_mean_x_max_u
#       I : Curve.Valid_h3_mean_x_max_u   (y)
#    Valid_h3_mean_x_mean_u
#       I : Curve.Valid_h3_mean_x_mean_u   (y)
#    Valid_h3_mean_x_min_u
#       I : Curve.Valid_h3_mean_x_min_u   (y)
#    Valid_h3_min_x_max_u
#       I : Curve.Valid_h3_min_x_max_u   (y)
#    Valid_h3_min_x_mean_u
#       I : Curve.Valid_h3_min_x_mean_u   (y)
#    Valid_h3_min_x_min_u
#       I : Curve.Valid_h3_min_x_min_u   (y)
#    Valid_h3_range_x_max_u
#       I : Curve.Valid_h3_range_x_max_u   (y)
#    Valid_h3_range_x_mean_u
#       I : Curve.Valid_h3_range_x_mean_u   (y)
#    Valid_h3_range_x_min_u
#       I : Curve.Valid_h3_range_x_min_u   (y)
#    Valid_h4_col_norms_max
#       I : Curve.Valid_h4_col_norms_max   (y)
#    Valid_h4_col_norms_mean
#       I : Curve.Valid_h4_col_norms_mean   (y)
#    Valid_h4_col_norms_min
#       I : Curve.Valid_h4_col_norms_min   (y)
#    Valid_h4_max_x_max_u
#       I : Curve.Valid_h4_max_x_max_u   (y)
#    Valid_h4_max_x_mean_u
#       I : Curve.Valid_h4_max_x_mean_u   (y)
#    Valid_h4_max_x_min_u
#       I : Curve.Valid_h4_max_x_min_u   (y)
#    Valid_h4_mean_x_max_u
#       I : Curve.Valid_h4_mean_x_max_u   (y)
#    Valid_h4_mean_x_mean_u
#       I : Curve.Valid_h4_mean_x_mean_u   (y)
#    Valid_h4_mean_x_min_u
#       I : Curve.Valid_h4_mean_x_min_u   (y)
#    Valid_h4_min_x_max_u
#       I : Curve.Valid_h4_min_x_max_u   (y)
#    Valid_h4_min_x_mean_u
#       I : Curve.Valid_h4_min_x_mean_u   (y)
#    Valid_h4_min_x_min_u
#       I : Curve.Valid_h4_min_x_min_u   (y)
#    Valid_h4_range_x_max_u
#       I : Curve.Valid_h4_range_x_max_u   (y)
#    Valid_h4_range_x_mean_u
#       I : Curve.Valid_h4_range_x_mean_u   (y)
#    Valid_h4_range_x_min_u
#       I : Curve.Valid_h4_range_x_min_u   (y)
#    Valid_h4_row_norms_max
#       I : Curve.Valid_h4_row_norms_max   (y)
#    Valid_h4_row_norms_mean
#       I : Curve.Valid_h4_row_norms_mean   (y)
#    Valid_h4_row_norms_min
#       I : Curve.Valid_h4_row_norms_min   (y)
#    Valid_objective
#       I : Curve.Valid_objective   (y)
#    Valid_term_0
#       I : Curve.Valid_term_0   (y)
#    Valid_term_1_weight_decay
#       I : Curve.Valid_term_1_weight_decay   (y)
#    Valid_y_y_1_col_norms_max
#       I : Curve.Valid_y_y_1_col_norms_max   (y)
#    Valid_y_y_1_col_norms_mean
#       I : Curve.Valid_y_y_1_col_norms_mean   (y)
#    Valid_y_y_1_col_norms_min
#       I : Curve.Valid_y_y_1_col_norms_min   (y)
#    Valid_y_y_1_max_max_class
#       I : Curve.Valid_y_y_1_max_max_class   (y)
#    Valid_y_y_1_mean_max_class
#       I : Curve.Valid_y_y_1_mean_max_class   (y)
#    Valid_y_y_1_min_max_class
#       I : Curve.Valid_y_y_1_min_max_class   (y)
#    Valid_y_y_1_misclass
#       I : Curve.Valid_y_y_1_misclass   (y)
#    Valid_y_y_1_nll
#       I : Curve.Valid_y_y_1_nll   (y)
#    Valid_y_y_1_row_norms_max
#       I : Curve.Valid_y_y_1_row_norms_max   (y)
#    Valid_y_y_1_row_norms_mean
#       I : Curve.Valid_y_y_1_row_norms_mean   (y)
#    Valid_y_y_1_row_norms_min
#       I : Curve.Valid_y_y_1_row_norms_min   (y)
#    Valid_y_y_2_col_norms_max
#       I : Curve.Valid_y_y_2_col_norms_max   (y)
#    Valid_y_y_2_col_norms_mean
#       I : Curve.Valid_y_y_2_col_norms_mean   (y)
#    Valid_y_y_2_col_norms_min
#       I : Curve.Valid_y_y_2_col_norms_min   (y)
#    Valid_y_y_2_max_max_class
#       I : Curve.Valid_y_y_2_max_max_class   (y)
#    Valid_y_y_2_mean_max_class
#       I : Curve.Valid_y_y_2_mean_max_class   (y)
#    Valid_y_y_2_min_max_class
#       I : Curve.Valid_y_y_2_min_max_class   (y)
#    Valid_y_y_2_misclass
#       I : Curve.Valid_y_y_2_misclass   (y)
#    Valid_y_y_2_nll
#       I : Curve.Valid_y_y_2_nll   (y)
#    Valid_y_y_2_row_norms_max
#       I : Curve.Valid_y_y_2_row_norms_max   (y)
#    Valid_y_y_2_row_norms_mean
#       I : Curve.Valid_y_y_2_row_norms_mean   (y)
#    Valid_y_y_2_row_norms_min
#       I : Curve.Valid_y_y_2_row_norms_min   (y)
#    Valid_y_y_3_col_norms_max
#       I : Curve.Valid_y_y_3_col_norms_max   (y)
#    Valid_y_y_3_col_norms_mean
#       I : Curve.Valid_y_y_3_col_norms_mean   (y)
#    Valid_y_y_3_col_norms_min
#       I : Curve.Valid_y_y_3_col_norms_min   (y)
#    Valid_y_y_3_max_max_class
#       I : Curve.Valid_y_y_3_max_max_class   (y)
#    Valid_y_y_3_mean_max_class
#       I : Curve.Valid_y_y_3_mean_max_class   (y)
#    Valid_y_y_3_min_max_class
#       I : Curve.Valid_y_y_3_min_max_class   (y)
#    Valid_y_y_3_misclass
#       I : Curve.Valid_y_y_3_misclass   (y)
#    Valid_y_y_3_nll
#       I : Curve.Valid_y_y_3_nll   (y)
#    Valid_y_y_3_row_norms_max
#       I : Curve.Valid_y_y_3_row_norms_max   (y)
#    Valid_y_y_3_row_norms_mean
#       I : Curve.Valid_y_y_3_row_norms_mean   (y)
#    Valid_y_y_3_row_norms_min
#       I : Curve.Valid_y_y_3_row_norms_min   (y)
#    Valid_y_y_4_col_norms_max
#       I : Curve.Valid_y_y_4_col_norms_max   (y)
#    Valid_y_y_4_col_norms_mean
#       I : Curve.Valid_y_y_4_col_norms_mean   (y)
#    Valid_y_y_4_col_norms_min
#       I : Curve.Valid_y_y_4_col_norms_min   (y)
#    Valid_y_y_4_max_max_class
#       I : Curve.Valid_y_y_4_max_max_class   (y)
#    Valid_y_y_4_mean_max_class
#       I : Curve.Valid_y_y_4_mean_max_class   (y)
#    Valid_y_y_4_min_max_class
#       I : Curve.Valid_y_y_4_min_max_class   (y)
#    Valid_y_y_4_misclass
#       I : Curve.Valid_y_y_4_misclass   (y)
#    Valid_y_y_4_nll
#       I : Curve.Valid_y_y_4_nll   (y)
#    Valid_y_y_4_row_norms_max
#       I : Curve.Valid_y_y_4_row_norms_max   (y)
#    Valid_y_y_4_row_norms_mean
#       I : Curve.Valid_y_y_4_row_norms_mean   (y)
#    Valid_y_y_4_row_norms_min
#       I : Curve.Valid_y_y_4_row_norms_min   (y)
#    Valid_y_y_5_col_norms_max
#       I : Curve.Valid_y_y_5_col_norms_max   (y)
#    Valid_y_y_5_col_norms_mean
#       I : Curve.Valid_y_y_5_col_norms_mean   (y)
#    Valid_y_y_5_col_norms_min
#       I : Curve.Valid_y_y_5_col_norms_min   (y)
#    Valid_y_y_5_max_max_class
#       I : Curve.Valid_y_y_5_max_max_class   (y)
#    Valid_y_y_5_mean_max_class
#       I : Curve.Valid_y_y_5_mean_max_class   (y)
#    Valid_y_y_5_min_max_class
#       I : Curve.Valid_y_y_5_min_max_class   (y)
#    Valid_y_y_5_misclass
#       I : Curve.Valid_y_y_5_misclass   (y)
#    Valid_y_y_5_nll
#       I : Curve.Valid_y_y_5_nll   (y)
#    Valid_y_y_5_row_norms_max
#       I : Curve.Valid_y_y_5_row_norms_max   (y)
#    Valid_y_y_5_row_norms_mean
#       I : Curve.Valid_y_y_5_row_norms_mean   (y)
#    Valid_y_y_5_row_norms_min
#       I : Curve.Valid_y_y_5_row_norms_min   (y)
#    Valid_y_y_6_col_norms_max
#       I : Curve.Valid_y_y_6_col_norms_max   (y)
#    Valid_y_y_6_col_norms_mean
#       I : Curve.Valid_y_y_6_col_norms_mean   (y)
#    Valid_y_y_6_col_norms_min
#       I : Curve.Valid_y_y_6_col_norms_min   (y)
#    Valid_y_y_6_max_max_class
#       I : Curve.Valid_y_y_6_max_max_class   (y)
#    Valid_y_y_6_mean_max_class
#       I : Curve.Valid_y_y_6_mean_max_class   (y)
#    Valid_y_y_6_min_max_class
#       I : Curve.Valid_y_y_6_min_max_class   (y)
#    Valid_y_y_6_misclass
#       I : Curve.Valid_y_y_6_misclass   (y)
#    Valid_y_y_6_nll
#       I : Curve.Valid_y_y_6_nll   (y)
#    Valid_y_y_6_row_norms_max
#       I : Curve.Valid_y_y_6_row_norms_max   (y)
#    Valid_y_y_6_row_norms_mean
#       I : Curve.Valid_y_y_6_row_norms_mean   (y)
#    Valid_y_y_6_row_norms_min
#       I : Curve.Valid_y_y_6_row_norms_min   (y)

# %%
means = [c for c in sorted(m.monitor.channels.keys()) if "mean" in c and "norm" in c]
make_curves(m,*means)
# Out:
#    Train_h1_kernel_norms_mean
#       I : Curve.Train_h1_kernel_norms_mean   (y)
#    Train_h2_kernel_norms_mean
#       I : Curve.Train_h2_kernel_norms_mean   (y)
#    Train_h3_kernel_norms_mean
#       I : Curve.Train_h3_kernel_norms_mean   (y)
#    Train_h4_col_norms_mean
#       I : Curve.Train_h4_col_norms_mean   (y)
#    Train_h4_row_norms_mean
#       I : Curve.Train_h4_row_norms_mean   (y)
#    Train_y_y_1_col_norms_mean
#       I : Curve.Train_y_y_1_col_norms_mean   (y)
#    Train_y_y_1_row_norms_mean
#       I : Curve.Train_y_y_1_row_norms_mean   (y)
#    Train_y_y_2_col_norms_mean
#       I : Curve.Train_y_y_2_col_norms_mean   (y)
#    Train_y_y_2_row_norms_mean
#       I : Curve.Train_y_y_2_row_norms_mean   (y)
#    Train_y_y_3_col_norms_mean
#       I : Curve.Train_y_y_3_col_norms_mean   (y)
#    Train_y_y_3_row_norms_mean
#       I : Curve.Train_y_y_3_row_norms_mean   (y)
#    Train_y_y_4_col_norms_mean
#       I : Curve.Train_y_y_4_col_norms_mean   (y)
#    Train_y_y_4_row_norms_mean
#       I : Curve.Train_y_y_4_row_norms_mean   (y)
#    Train_y_y_5_col_norms_mean
#       I : Curve.Train_y_y_5_col_norms_mean   (y)
#    Train_y_y_5_row_norms_mean
#       I : Curve.Train_y_y_5_row_norms_mean   (y)
#    Train_y_y_6_col_norms_mean
#       I : Curve.Train_y_y_6_col_norms_mean   (y)
#    Train_y_y_6_row_norms_mean
#       I : Curve.Train_y_y_6_row_norms_mean   (y)
#    Valid_h1_kernel_norms_mean
#       I : Curve.Valid_h1_kernel_norms_mean   (y)
#    Valid_h2_kernel_norms_mean
#       I : Curve.Valid_h2_kernel_norms_mean   (y)
#    Valid_h3_kernel_norms_mean
#       I : Curve.Valid_h3_kernel_norms_mean   (y)
#    Valid_h4_col_norms_mean
#       I : Curve.Valid_h4_col_norms_mean   (y)
#    Valid_h4_row_norms_mean
#       I : Curve.Valid_h4_row_norms_mean   (y)
#    Valid_y_y_1_col_norms_mean
#       I : Curve.Valid_y_y_1_col_norms_mean   (y)
#    Valid_y_y_1_row_norms_mean
#       I : Curve.Valid_y_y_1_row_norms_mean   (y)
#    Valid_y_y_2_col_norms_mean
#       I : Curve.Valid_y_y_2_col_norms_mean   (y)
#    Valid_y_y_2_row_norms_mean
#       I : Curve.Valid_y_y_2_row_norms_mean   (y)
#    Valid_y_y_3_col_norms_mean
#       I : Curve.Valid_y_y_3_col_norms_mean   (y)
#    Valid_y_y_3_row_norms_mean
#       I : Curve.Valid_y_y_3_row_norms_mean   (y)
#    Valid_y_y_4_col_norms_mean
#       I : Curve.Valid_y_y_4_col_norms_mean   (y)
#    Valid_y_y_4_row_norms_mean
#       I : Curve.Valid_y_y_4_row_norms_mean   (y)
#    Valid_y_y_5_col_norms_mean
#       I : Curve.Valid_y_y_5_col_norms_mean   (y)
#    Valid_y_y_5_row_norms_mean
#       I : Curve.Valid_y_y_5_row_norms_mean   (y)
#    Valid_y_y_6_col_norms_mean
#       I : Curve.Valid_y_y_6_col_norms_mean   (y)
#    Valid_y_y_6_row_norms_mean
#       I : Curve.Valid_y_y_6_row_norms_mean   (y)

# %% [markdown]
# Weights Learned
# =====
#
# We can look at the weights learned by this model compared with our most recent best model and see what the differences are. Although, this might be difficult to interpret.

# %%
# %env PYLEARN2_VIEWER_COMMAND=/afs/inf.ed.ac.uk/user/s08/s0805516/repos/neukrill-net-work/image_hack.sh
# %run ~/repos/pylearn2/pylearn2/scripts/show_weights.py /disk/scratch/neuroglycerin/models/quicker_learning_1_fc_layer_experiment_no_norms_repeat_recent.pkl
# Out:
# env: PYLEARN2_VIEWER_COMMAND=/afs/inf.ed.ac.uk/user/s08/s0805516/repos/neukrill-net-work/image_hack.sh
# making weights report
# loading model
# loading done
# smallest enc weight magnitude: 9.72501584329e-06
# mean enc weight magnitude: 0.0884661450982
# max enc weight magnitude: 0.975871086121

# %%
from IPython.display import Image

# %%
def plot_recent_pylearn2():
    pl2plt = Image(filename="/afs/inf.ed.ac.uk/user/s08/s0805516/tmp/pylearnplot.png", width=700)
    return pl2plt
plot_recent_pylearn2()

# %%
# %run ~/repos/pylearn2/pylearn2/scripts/show_weights.py /disk/scratch/neuroglycerin/models/experiment_biglayer_largedecay_recent.pkl

# %%
plot_recent_pylearn2()
