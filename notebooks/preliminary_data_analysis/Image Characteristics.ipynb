# %% [markdown]
# As I've not used virtualenvs much before, making sure that it's working in the notebook:

# %%
# !pip freeze
# Out:
# Jinja2==2.7.3
# MarkupSafe==0.23
# Pillow==2.7.0
# argparse==1.2.1
# backports.ssl-match-hostname==3.4.0.2
# certifi==14.05.14
# ipython==2.4.0
# matplotlib==1.4.3
# mock==1.0.1
# -e git+git@github.com:Neuroglycerin/neukrill-net-tools.git@5cc6d9353c5a4f301645fb5728a3e380b0cba5a1#egg=neukrill_net-master
# nose==1.3.4
# numpy==1.9.1
# py==1.4.26
# pyparsing==2.0.3
# pytest==2.6.4
# python-dateutil==2.4.0
# pytz==2014.10
# pyzmq==14.5.0
# scikit-image==0.10.1
# scikit-learn==0.15.2
# scipy==0.14.0
# six==1.8.0
# tornado==4.1
# wsgiref==0.1.2

# %% [markdown]
# Looks good. Checking path:

# %%
import sys
print(sys.path)
# Out:
# ['', '/home/scott/Documents/git/neukrill-net-tools', '/home/scott/Documents/git/neukrill-venv2/lib/python2.7', '/home/scott/Documents/git/neukrill-venv2/lib/python2.7/plat-x86_64-linux-gnu', '/home/scott/Documents/git/neukrill-venv2/lib/python2.7/lib-tk', '/home/scott/Documents/git/neukrill-venv2/lib/python2.7/lib-old', '/home/scott/Documents/git/neukrill-venv2/lib/python2.7/lib-dynload', '/usr/lib/python2.7', '/usr/lib/python2.7/plat-x86_64-linux-gnu', '/usr/lib/python2.7/lib-tk', '/home/scott/Documents/git/neukrill-venv2/local/lib/python2.7/site-packages', '/home/scott/Documents/git/neukrill-venv2/lib/python2.7/site-packages', '/home/scott/Documents/git/neukrill-venv2/local/lib/python2.7/site-packages/IPython/extensions']

# %% [markdown]
# Tools repository has been added succesfully.

# %% [markdown]
# Aims
# ====
#
# Want to investigate the images in various ways. Want to simply look at the different classes and make a record of the different sizes. Also would like to investigate other factors, like image statistics and visualize similarities using dimensionality reduction. Making a list:
#
# * ~~List the classes and superclasses~~
# * ~~Look at examples from different classes~~
# * ~~Distribution of image dimensions (heatmap)~~
# * ~~Class proportions~~
# * Image statistics (define more accurately when you get here)
# * Visualize similarities (dimensionality reduction etc)
#
# First, parsing the images:

# %%
cd ..
# Out:
# /home/scott/Documents/git/neukrill-net-work

# %%
import neukrill_net.utils

# %%
settings = neukrill_net.utils.Settings('settings.json')

# %%
imagedict = settings.image_fnames['train']

# %% [markdown]
# Classes
# =======
#
# They are described in the [pdf provided with the data][kgl]. In that pdf you can also see the superclasses these are divided into. We can get them from the filenames as follows:
#
# [kgl]: https://kaggle2.blob.core.windows.net/competitions-data/kaggle/3978/plankton_identification.pdf?sv=2012-02-12&se=2015-01-11T21%3A24%3A07Z&sr=b&sp=r&sig=VW1F1UnNvUs3H0KHYRoxGakhlla3SHCYOk9iImymihs%3D

# %%
classes = list(imagedict.keys())
# copy the list
temp_classes = classes[:]
while len(temp_classes) > 0:
    # take three off the temp list on each iteration and print them
    # with tabs in between, catching the last few with the if
    if len(temp_classes) < 3:
        print("\t".join([temp_classes.pop() for i in range(len(temp_classes))]))
    else:
        print("\t".join([temp_classes.pop() for i in range(3)]))
# Out:
# protist_noctiluca	polychaete	tunicate_doliolid
# hydromedusae_shapeA_sideview_small	fish_larvae_myctophids	copepod_calanoid_large
# hydromedusae_other	protist_dark_center	acantharia_protist_big_center
# hydromedusae_solmaris	fish_larvae_thin_body	tunicate_partial
# jellies_tentacles	hydromedusae_shapeA	hydromedusae_shapeB
# diatom_chain_tube	shrimp_caridean	copepod_cyclopoid_copilia
# siphonophore_other_parts	diatom_chain_string	echinoderm_larva_pluteus_brittlestar
# ctenophore_cydippid_no_tentacles	euphausiids_young	tunicate_doliolid_nurse
# chaetognath_other	fish_larvae_medium_body	hydromedusae_bell_and_tentacles
# fecal_pellet	tunicate_salp	ephyra
# hydromedusae_narcomedusae	shrimp_sergestidae	copepod_cyclopoid_oithona_eggs
# protist_fuzzy_olive	siphonophore_calycophoran_rocketship_young	invertebrate_larvae_other_B
# decapods	unknown_blobs_and_smudges	radiolarian_chain
# euphausiids	hydromedusae_typeD_bell_and_tentacles	echinoderm_larva_pluteus_urchin
# ...

# %% [markdown]
# Super Classes
# =============
#
# We want a list of these, because then we can split up the above with some work. Think the only option is to write it by hand. There is a problem with this, because _the classes don't all have their superclass in their name_. Most of them do, but not all. Examples are some Shrimp-likes, others in crustaceans, heteropods and fecal pellets. So these superclasses are __incomplete__. To fix it we'd need to make a dictionary, with each of the classes sorted into the right corresponding superclasses.

# %%
superclasses = ['tricho', 'diatom', 'chordate', 'polychaete',
                'ctenophore', 'siphonophore', 'hydromedusae',
                'tunicate', 'ephyra', 'jellies', 'appendicularian',
                'fish', 'copepod', 'shrimp', 'chaetognath',
                'pteropod', 'detritus', 'larvae', 'echinoderm',
                'unknown']

# %%
# splitting the classes into approximate super classes
split_by_superclass = {}
for sc in superclasses:
    split_by_superclass[sc] = []
for c in classes:
    for sc in superclasses:
        if sc in c:
            split_by_superclass[sc] += [c]

# %% [markdown]
# Viewing the images
# ==================
#
# Difficult to view this many images at the same time, even looking at single examples from
# each class would be hard. Going to look at examples from each superclass.

# %%
from IPython.display import display
from IPython.display import Image
from IPython.display import HTML

# %%
examples = imagedict[split_by_superclass[superclasses[0]][0]]

# %% [markdown]
# Annoyingly, these are arranged vertically. There [are ways to arrange them side by side](https://stackoverflow.com/questions/17439176/ipython-notebook-how-to-display-multiple-objects-without-newline), so maybe we can fix that sometime. We've got bigger fish to fry though.

# %%
for e in examples[:3]:
    s = """{0}""".format(superclasses[0])
    h = HTML(s)
    display(s)
    i = Image(e)
    display(i)
# Out:
# 'tricho'
# 'tricho'
# 'tricho'

# %% [markdown]
# Then, iterating through the rest:

# %%
for sc in superclasses:
    examples = imagedict[split_by_superclass[sc][0]]
    for e in examples[:3]:
        s = """{0}""".format(sc)
        h = HTML(s)
        display(s)
        i = Image(e)
        display(i)
# Out:
# 'tricho'
# 'tricho'
# 'tricho'
# 'diatom'
# 'diatom'
# 'diatom'
# 'chordate'
# 'chordate'
# 'chordate'
# 'polychaete'
# 'polychaete'
# 'polychaete'
# 'ctenophore'
# 'ctenophore'
# 'ctenophore'
# 'siphonophore'
# 'siphonophore'
# 'siphonophore'
# 'hydromedusae'
# 'hydromedusae'
# 'hydromedusae'
# 'tunicate'
# 'tunicate'
# 'tunicate'
# 'ephyra'
# 'ephyra'
# 'ephyra'
# 'jellies'
# 'jellies'
# 'jellies'
# 'appendicularian'
# 'appendicularian'
# 'appendicularian'
# 'fish'
# 'fish'
# 'fish'
# 'copepod'
# 'copepod'
# 'copepod'
# 'shrimp'
# 'shrimp'
# 'shrimp'
# 'chaetognath'
# 'chaetognath'
# 'chaetognath'
# 'pteropod'
# 'pteropod'
# 'pteropod'
# 'detritus'
# 'detritus'
# 'detritus'
# 'larvae'
# 'larvae'
# 'larvae'
# 'echinoderm'
# 'echinoderm'
# 'echinoderm'
# 'unknown'
# 'unknown'
# 'unknown'

# %% [markdown]
# For a much better vizualization of these classes and their relationships, see [here][].
# Now, we can see that some of these images are clearly __much__ bigger than others.
# The question is, what does this distribution of different dimensions look like?
#
# [here]: https://npow.github.io/plankton/viewer/index.html

# %% [markdown]
# Image Dimensions
# ================
#
# Aiming to plot two things: a 2D heatmap of x and y dimensions and a histogram of no. of pixels in the images.
#
# To do this, first we're going to have to load these images into numpy:

# %%
import skimage.io
import numpy as np

# %%
image_array_dict = {}
for i,c in enumerate(classes):
    #print("class: {0} of 120: {1}".format(i,c))
    image_fpaths = imagedict[c]
    # dictionary will contain lists of numpy arrays
    image_array_dict[c] = []
    # iterate over all paths adding to list in dictionary
    for fpath in image_fpaths:
        image_array_dict[c].append(skimage.io.imread(fpath))

# %%
# build a list of dimensions
dimensions = [image_array.shape for imagelist in list(image_array_dict.values()) for image_array in imagelist]

# %% [markdown]
# My code is [copied shamelessly from stackexchange](https://stackoverflow.com/questions/2369492/generate-a-heatmap-in-matplotlib-using-a-scatter-data-set).

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = 12, 8
plt.rcParams['axes.grid'] = True
plt.set_cmap('brg')

# %%
x,y = zip(*dimensions)

# %%
plt.title("distribution of x dimension")
h = plt.hist(x, bins=50)

# %%
plt.title("distribution of y dimension")
h = plt.hist(y, bins=50)

# %%
plt.clf()
plt.scatter(x,y,s=0.05)
plt.show()

# %%
heatmap, xedges, yedges = np.histogram2d(x, y, bins=50)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.title("Joint distribution")
plt.clf()
plt.imshow(heatmap, extent=extent)
plt.show()

# %% [markdown]
# Looks like a [exponential-logarithmic distribution](https://en.wikipedia.org/wiki/Exponential-logarithmic_distribution).

# %% [markdown]
# ### Now lets try that again, but this time make sure all the images are landscape

# %%
import neukrill_net.image_processing

# %%
# build a list of dimensions
dimensions = [neukrill_net.image_processing.landscapise_image(image_array).shape
                  for imagelist in list(image_array_dict.values())
                  for image_array in imagelist]

# %%
x,y = zip(*dimensions)

# %%
plt.title("distribution of x dimension")
h = plt.hist(x, bins=50)
print('Max number of rows is {}'.format(np.max(x)))
# Out:
# Max number of rows is 399

# %%
plt.title("distribution of y dimension")
h = plt.hist(y, bins=50)
print('Max number of columns is {}'.format(np.max(y)))
# Out:
# Max number of columns is 428

# %%
plt.clf()
plt.scatter(x,y,s=0.05)
plt.show()

# %%
heatmap, xedges, yedges = np.histogram2d(x, y, bins=50)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

plt.title("Joint distribution")
plt.clf()
plt.imshow(heatmap, extent=extent)
plt.show()

# %% [markdown]
# Class Proportions
# =================
#
# How are the classes distributed? Do we have way more of some examples than others?

# %%
# dictionary of classes as keys and number of examples for values
n_examples = {}
for c in classes:
    n_examples[c] = len(imagedict[c])

# %%
plt.title("Histogram of class sizes.")
plt.ylabel("Number of examples")
h=plt.hist(list(n_examples.values()),bins=50)

# %% [markdown]
# That doesn't look good, some classes have _very few examples_. How bad is it? Let's look at only the classes with less than 250 examples:

# %%
plt.title("Histogram of class sizes less than 250")
plt.ylabel("Number of examples")
lessthan250 = [n for n in list(n_examples.values()) if n < 250]
h=plt.hist(lessthan250,bins=50)

# %% [markdown]
# That's very bad, quite a few classes have only about 10 examples.
# Which classes are they?

# %%
ks = [k for k in classes if n_examples[k] < 50]
lessthan50 = [n_examples[k] for k in ks]
fig, ax = plt.subplots()
ind = range(len(lessthan50))
ax.bar(ind,lessthan50)
ax.set_xticks(np.array(ind)+0.5)
ax.set_xticklabels(ks,rotation=90)
ax.set_title("Classes with less than 50 examples.")
plt.show()

# %% [markdown]
# Vizualizing Similarities
# ========================
#
# Applying dimensionality reduction, we can try to view the similarities between these data points.
# By colouring, we should be able to see if there are obvious differences between classes.

# %%
import imp
imp.reload(neukrill_net.utils)
import skimage.transform

# %%
processing = lambda image: skimage.transform.resize(image, (48,48))

# %%
data,labels = neukrill_net.utils.load_data(settings.image_fnames, classes=settings.classes, processing=processing, verbose=True)
# Out:
# class: 0 of 120: acantharia_protist
# image read: 0 of 889
# image read: 1 of 889
# image read: 2 of 889
# image read: 3 of 889
# image read: 4 of 889
# image read: 5 of 889
# image read: 6 of 889
# image read: 7 of 889
# image read: 8 of 889
# image read: 9 of 889
# image read: 10 of 889
# image read: 11 of 889
# image read: 12 of 889
# image read: 13 of 889
# image read: 14 of 889
# image read: 15 of 889
# image read: 16 of 889
# image read: 17 of 889
# image read: 18 of 889
# image read: 19 of 889
# image read: 20 of 889
# image read: 21 of 889
# image read: 22 of 889
# image read: 23 of 889
# image read: 24 of 889
# image read: 25 of 889
# image read: 26 of 889
# image read: 27 of 889
# image read: 28 of 889
# image read: 29 of 889
# image read: 30 of 889
# image read: 31 of 889
# image read: 32 of 889
# image read: 33 of 889
# image read: 34 of 889
# image read: 35 of 889
# image read: 36 of 889
# image read: 37 of 889
# image read: 38 of 889
# image read: 39 of 889
# ...

# %%
# stack to make an array
data = np.vstack(data)

# %%
labels = np.hstack(labels)

# %%
import sklearn.preprocessing

# %%
import sklearn.decomposition

# %% [markdown]
# Have to use the superclasses, otherwise this graph is going to be even _less_ useful.

# %%
sclabels = []
for i,l in enumerate(labels):
    # not the fastest code
    for sc in superclasses:
        if l in split_by_superclass[sc]:
            sclabels.append(sc)
    # this is such a stupid piece of code
    if len(sclabels) < i+1:
        sclabels.append("other")
sclabels = np.hstack(sclabels)

# %%
label_encoder = sklearn.preprocessing.LabelEncoder()
sclabels_encoded = label_encoder.fit_transform(sclabels)

# %% [markdown]
# Taking a sub-sample of the full data, as most of these methods don't seem to respond well to such a large array.

# %%
import random

# %%
random.seed(42)
sample_inds = list(range(data.shape[0]))
random.shuffle(sample_inds)
N_samples = 1000

# %%
X = data[sample_inds[:N_samples],:]
y = sclabels[sample_inds[:N_samples]]

# %%
pca = sklearn.decomposition.PCA(n_components=2)
Xpca = pca.fit_transform(X)

# %%
def scatter_with_legend(X,labels,title=None):
    """I'll be here all day if I have to rewrite this
    every time. Plots a scatter plot with colours and
    a legend.
    
    This is so much more difficult than it should be."""
    if title:
        plt.title(title)
    import matplotlib.cm
    label_encoder = sklearn.preprocessing.LabelEncoder()
    labels_encoded = label_encoder.fit_transform(labels)
    m = max(labels_encoded)
    # split reduced data by the encoded labels
    split_by_labels = {}
    for l in labels_encoded:
        split_by_labels[l] = []
    for p,l in zip(X,labels_encoded):
        split_by_labels[l].append(p)
    # then plot each of these
    scatter_dict = {}
    for k in split_by_labels.keys():
        cls = label_encoder.inverse_transform(k)
        scatter_dict[cls] = plt.scatter(*zip(*split_by_labels[k]),
                                        c=matplotlib.cm.gnuplot2(k/m),alpha=0.6)
    # then tell the legend which is which
    classes = list(scatter_dict.keys())
    scatterplots = [scatter_dict[k] for k in classes]
    plt.legend(scatterplots,classes)
scatter_with_legend(Xpca,y,"PCA projection of 1000 randomly sampled points")

# %% [markdown]
# Trying some other samples to see what we end up with:

# %%
random.seed(500)
sample_inds = list(range(data.shape[0]))
random.shuffle(sample_inds)
N_samples = 1000

# %%
X = data[sample_inds[:N_samples],:]
y = sclabels[sample_inds[:N_samples]]

# %%
pca = sklearn.decomposition.PCA(n_components=2)
Xpca = pca.fit_transform(X)

# %%
scatter_with_legend(Xpca,y,title="PCA projection of 1000 randomly sampled points.")

# %%
random.seed(1)
sample_inds = list(range(data.shape[0]))
random.shuffle(sample_inds)
N_samples = 1000

# %%
X = data[sample_inds[:N_samples],:]
y = sclabels[sample_inds[:N_samples]]

# %%
pca = sklearn.decomposition.PCA(n_components=2)
Xpca = pca.fit_transform(X)

# %%
scatter_with_legend(Xpca,y,title="PCA projection of 1000 randomly sampled points.")

# %% [markdown]
# Ok, so we can see a group of tricho escaping on the left hand side. Not much other than that.
# Trying another type of [manifold learning][m]: Isomap.
#
# [m]: http://scikit-learn.org/stable/modules/manifold.html

# %%
import sklearn.manifold

# %%
random.seed(1)
sample_inds = list(range(data.shape[0]))
random.shuffle(sample_inds)
N_samples = 1000
X = data[sample_inds[:N_samples],:]
y = sclabels[sample_inds[:N_samples]]

# %% [markdown]
# Going to have to try this with some different settings for the n_neighbours:

# %%
for i,n in enumerate([1,5,10,20]):
    isomap = sklearn.manifold.Isomap(n_neighbors=n)
    Xisomap = isomap.fit_transform(X)
    scatter_with_legend(Xisomap,y,title="Isomap projection with 1000 randomly sampled data points with n_neighbors={0}".format(n))
    plt.show()

# %% [markdown]
# Doesn't appear to make much difference.
# Leaving the defaults we can try different random seeds:

# %%
for s in [42,34,55,22]:
    random.seed(s)
    sample_inds = list(range(data.shape[0]))
    random.shuffle(sample_inds)
    N_samples = 1000
    X = data[sample_inds[:N_samples],:]
    y = sclabels[sample_inds[:N_samples]]
    isomap = sklearn.manifold.Isomap(n_neighbors=5)
    Xisomap = isomap.fit_transform(X)
    scatter_with_legend(Xisomap,y,title="Isomap projection with 5000 randomly sampled data points with seed {0}".format(s))
    plt.show()

# %% [markdown]
# Again, the yellower points seem to spread out more, but that's just about all we can conclude about that.
# Finally, trying t-SNE to see if it's going to do any better (probably not).

# %%
random.seed(1)
sample_inds = list(range(data.shape[0]))
random.shuffle(sample_inds)
N_samples = 1000

# %%
X = data[sample_inds[:N_samples],:]
y = sclabels[sample_inds[:N_samples]]

# %%
tsne = sklearn.manifold.t_sne.TSNE()
Xtsne = tsne.fit_transform(X)

# %%
scatter_with_legend(Xtsne,y,title="t-SNE projection of 1000 randomly sampled points.")

# %% [markdown]
# This time, the clustering of the yellow trichos looks more obvious. Also, there is maybe a cluster of copepods in the top right to middle.
