# %% [markdown]
# In the last notebook compared pip freeze output and installed packages so that it matched. Did not find error. Must be some other difference in the virtualenv. So, going to use rsync to compare _everything_ in both venvs.

# %%
cd ../..
# Out:
# /afs/inf.ed.ac.uk/user/s08/s0805516/repos

# %% [markdown]
# Using `rsync` with `n` for dry run, `r` for recursive, `t` for ignore timestamps and `l` to compare symlinks.

# %%
# !rsync -nrvl --ignore-times --size-only --exclude={*.pyc,*.so} neukrill_venv2/ neukrillvenvfresh/
# Out:
# sending incremental file list
# bin/activate
# bin/activate.csh
# bin/activate.fish
# bin/easy_install
# bin/easy_install-2.7
# bin/f2py2.7
# bin/ipcluster
# bin/ipcluster2
# bin/ipcontroller
# bin/ipcontroller2
# bin/ipengine
# bin/ipengine2
# bin/iptest
# bin/iptest2
# bin/ipython
# bin/ipython2
# bin/jsonschema
# bin/nosetests
# bin/nosetests-2.7
# bin/pilconvert.py
# bin/pildriver.py
# bin/pilfile.py
# bin/pilfont.py
# bin/pilprint.py
# bin/pip
# bin/pip-2.7
# bin/py.test
# bin/py.test-2.7
# bin/pygmentize
# bin/pylearn2-plot-monitor
# bin/pylearn2-print-monitor
# bin/pylearn2-show-examples
# bin/pylearn2-show-weights
# bin/pylearn2-train
# bin/skivi
# bin/theano-cache
# bin/theano-nose
# bin/theano-test
# lib/python2.7/site-packages/matplotlib-1.4.3-py2.7.egg-info/requires.txt
# lib/python2.7/site-packages/numbergen/__init__.py
# lib/python2.7/site-packages/numpy/__config__.py
# lib/python2.7/site-packages/numpy/core/lib/libnpymath.a
# ...

# %%
# !rsync -nrvl neukrillvenvfresh/ neukrill_venv2/
# Out:
# sending incremental file list
# bin/activate
# bin/activate.csh
# bin/activate.fish
# bin/activate_this.py
# bin/easy_install
# bin/easy_install-2.7
# bin/f2py2.7
# bin/ipcluster
# bin/ipcluster2
# bin/ipcontroller
# bin/ipcontroller2
# bin/ipengine
# bin/ipengine2
# bin/iptest
# bin/iptest2
# bin/ipython
# bin/ipython2
# bin/jsonschema
# bin/nosetests
# bin/nosetests-2.7
# bin/pilconvert.py
# bin/pildriver.py
# bin/pilfile.py
# bin/pilfont.py
# bin/pilprint.py
# bin/pip
# bin/pip-2.7
# bin/py.test
# bin/py.test-2.7
# bin/pygmentize
# bin/pylearn2-plot-monitor
# bin/pylearn2-print-monitor
# bin/pylearn2-show-examples
# bin/pylearn2-show-weights
# bin/pylearn2-train
# bin/python2.7
# bin/skivi
# bin/theano-cache
# bin/theano-nose
# bin/theano-test
# lib/python2.7/UserDict.pyc
# lib/python2.7/_abcoll.pyc
# lib/python2.7/_weakrefset.pyc
# lib/python2.7/abc.pyc
# lib/python2.7/codecs.pyc
# lib/python2.7/copy_reg.pyc
# lib/python2.7/fnmatch.pyc
# lib/python2.7/genericpath.pyc
# ...

# %% [markdown]
# So they're the same? Tarballing and comparing the md5sums?
