# %%
# !pip freeze
# Out:
# Jinja2==2.7.3
# MarkupSafe==0.23
# Pillow==2.7.0
# PyYAML==3.11
# Pygments==2.0.2
# Theano==0.6.0
# argparse==1.2.1
# backports.ssl-match-hostname==3.4.0.2
# certifi==14.05.14
# holoviews==0.7
# ipython==3.0.0
# jsonschema==2.4.0
# mahotas==1.2.4
# matplotlib==1.4.3
# mistune==0.5
# mock==1.0.1
# -e git+git@github.com:Neuroglycerin/neukrill-net-tools.git@12dc21aecadd2e6958dccc35bd91daaa3ebf957f#egg=neukrill_net-master
# nose==1.3.4
# numpy==1.9.1
# param==1.2.1
# ptyprocess==0.4
# py==1.4.26
# -e git+https://github.com/lisa-lab/pylearn2.git@cf3999e7183f8dcaccccf4dfd2a31bbe3a948a97#egg=pylearn2-neukrillnetchosencommit
# pyparsing==2.0.3
# pytest==2.6.4
# python-dateutil==2.4.0
# pytz==2014.10
# pyzmq==14.5.0
# scikit-image==0.10.1
# scikit-learn==0.15.2
# scipy==0.14.0
# six==1.8.0
# terminado==0.5
# tornado==4.1
# wsgiref==0.1.2

# %%
# %pylab
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib inline

# %%
cd ..
# Out:
# /home/scott/Documents/git/neukrill-net-work

# %%
cd ../neukrill-net-work
# Out:
# /home/scott/Documents/git/neukrill-net-work

# %%
import sys
import numpy as np
import skimage.io

# %%
import imp

# %%
import neukrill_net.utils as utils
import neukrill_net.image_processing as image_processing
import neukrill_net.augment as augment

# %%
from IPython.display import display
from IPython.display import Image
from IPython.display import HTML

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = skimage.io.imread('data/train/acantharia_protist/100224.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (66, 59)

# %%
imgplot = plt.imshow(img)
imgplot.set_cmap('gray')

# %%
augImg = image_processing.shear_image(img, -10)
iplot = plt.imshow(augImg)
iplot.set_cmap('gray')
show()

# %%
augFunc = augment.RandomAugment()
imgplot = plt.imshow(augFunc(img))
imgplot.set_cmap('gray')

# %%
reload(image_processing)
reload(augment)
# Out:
# <module 'neukrill_net.augment' from '/home/scott/Documents/git/neukrill-net-tools/neukrill_net/augment.py'>

# %%
img2 = image_processing.padcrop_image(img,3,0.1)
imgplot = plt.imshow(img2)
imgplot.set_cmap('gray')

# %%
augFunc = augment.RandomAugment(units='float64',rotate=-1,rotate_is_resizable=False,shunt=[-0.05,0,0.05])

# %%
imgplot = plt.imshow(augFunc(img))
imgplot.set_cmap('gray')

# %%
augFunc = augment.RandomAugment(units='float64',rotate=-1,rotate_is_resizable=False,flip=True,shear=20,shunt=0.075)

# %%
imgplot = plt.imshow(augFunc(img))
imgplot.set_cmap('gray')

# %%
augFunc = augment.RandomAugment(units='float64',shear=20)

# %%
imgplot = plt.imshow(augFunc(img))
imgplot.set_cmap('gray')
